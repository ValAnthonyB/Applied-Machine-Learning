# %%
import numpy as np
import tensorflow as tf

# load MNIST Digit data
data = tf.keras.datasets.mnist

# here data is split into 70,30 by default
(X_train, Y_train), (X_test, Y_test) = data.load_data()

# normalizing data
X_train = tf.keras.utils.normalize(X_train)
X_test = tf.keras.utils.normalize(X_test)

# checking shape of data
print(X_train.shape)
print(X_test.shape)

# function to create and compile model
def createModel(input_shape, num_classes, optimizer, loss, metrics):

    model = tf.keras.models.Sequential()  ##a feed forward model , created stack of layer on top of it
    model.add(tf.keras.layers.Input(shape=input_shape))
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(64, activation='relu'))
    model.add(tf.keras.layers.Dense(128, activation='relu'))
    model.add(tf.keras.layers.Dense(128, activation='relu'))
    model.add(tf.keras.layers.Dense(num_classes, activation='softmax'))

    model.compile(optimizer=optimizer, loss=loss, metrics=[metrics])

    return model

# model
model = createModel(input_shape=(28, 28), num_classes=10, optimizer='adam',
                    loss='sparse_categorical_crossentropy',
                    metrics='accuracy')

model.summary()

print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU'))) #print no of GPU device

model.fit(X_train, Y_train, epochs=30, validation_split=0.1)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 64)                50240
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 76,362
# Trainable params: 76,362
# Non-trainable params: 0
# _________________________________________________________________
# Num GPUs Available:  0
# Epoch 1/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.3006 - accuracy: 0.9088 - val_loss: 0.1143 - val_accuracy: 0.9665
# Epoch 2/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.1284 - accuracy: 0.9605 - val_loss: 0.1102 - val_accuracy: 0.9668
# Epoch 3/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0930 - accuracy: 0.9706 - val_loss: 0.1005 - val_accuracy: 0.9715
# Epoch 4/30
# 1688/1688 [==============================] - 3s 2ms/step - loss: 0.0742 - accuracy: 0.9767 - val_loss: 0.0864 - val_accuracy: 0.9745
# Epoch 5/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0591 - accuracy: 0.9811 - val_loss: 0.0871 - val_accuracy: 0.9760
# Epoch 6/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0506 - accuracy: 0.9832 - val_loss: 0.1090 - val_accuracy: 0.9710
# Epoch 7/30
# 1688/1688 [==============================] - 3s 2ms/step - loss: 0.0425 - accuracy: 0.9861 - val_loss: 0.0967 - val_accuracy: 0.9758
# Epoch 8/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0379 - accuracy: 0.9878 - val_loss: 0.0956 - val_accuracy: 0.9757
# Epoch 9/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0333 - accuracy: 0.9891 - val_loss: 0.0974 - val_accuracy: 0.9777
# Epoch 10/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0288 - accuracy: 0.9905 - val_loss: 0.0969 - val_accuracy: 0.9763
# Epoch 11/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0253 - accuracy: 0.9918 - val_loss: 0.1195 - val_accuracy: 0.9730
# Epoch 12/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0224 - accuracy: 0.9925 - val_loss: 0.1174 - val_accuracy: 0.9733
# Epoch 13/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0241 - accuracy: 0.9920 - val_loss: 0.1184 - val_accuracy: 0.9753
# Epoch 14/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0198 - accuracy: 0.9931 - val_loss: 0.0996 - val_accuracy: 0.9802
# Epoch 15/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0180 - accuracy: 0.9938 - val_loss: 0.1160 - val_accuracy: 0.9768
# Epoch 16/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0194 - accuracy: 0.9934 - val_loss: 0.1153 - val_accuracy: 0.9795
# Epoch 17/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0170 - accuracy: 0.9940 - val_loss: 0.1242 - val_accuracy: 0.9785
# Epoch 18/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0153 - accuracy: 0.9951 - val_loss: 0.1142 - val_accuracy: 0.9790
# Epoch 19/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0137 - accuracy: 0.9954 - val_loss: 0.1569 - val_accuracy: 0.9763
# Epoch 20/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0159 - accuracy: 0.9946 - val_loss: 0.1191 - val_accuracy: 0.9797
# Epoch 21/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0143 - accuracy: 0.9953 - val_loss: 0.1447 - val_accuracy: 0.9750
# Epoch 22/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0148 - accuracy: 0.9952 - val_loss: 0.1213 - val_accuracy: 0.9772
# Epoch 23/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0111 - accuracy: 0.9961 - val_loss: 0.1318 - val_accuracy: 0.9803
# Epoch 24/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0111 - accuracy: 0.9965 - val_loss: 0.1461 - val_accuracy: 0.9775
# Epoch 25/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0133 - accuracy: 0.9961 - val_loss: 0.1401 - val_accuracy: 0.9787
# Epoch 26/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0120 - accuracy: 0.9960 - val_loss: 0.1327 - val_accuracy: 0.9773
# Epoch 27/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0115 - accuracy: 0.9963 - val_loss: 0.1288 - val_accuracy: 0.9795
# Epoch 28/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0118 - accuracy: 0.9962 - val_loss: 0.1223 - val_accuracy: 0.9800
# Epoch 29/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0091 - accuracy: 0.9971 - val_loss: 0.1447 - val_accuracy: 0.9790
# Epoch 30/30
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0109 - accuracy: 0.9965 - val_loss: 0.1279 - val_accuracy: 0.9797

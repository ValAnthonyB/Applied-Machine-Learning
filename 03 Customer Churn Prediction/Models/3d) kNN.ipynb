# %%
# %matplotlib notebook

import scipy.stats
import numpy as np
import pandas as pd

from imblearn.over_sampling import SMOTE
from collections import Counter

import matplotlib.pyplot as plt

# %% [markdown]
# # Process the data

# %%
# Read the data
df = pd.read_csv('C:/Users/vabalagon/Desktop/Machine Learning Projects/Applied-Machine-Learning-Projects/Customer Churn Prediction/data/processed.csv')

# Get the features and target variable from the dataframe
X = df.drop(['state', 'area_code', 'churn'], axis=1).to_numpy()
y = df['churn'].to_numpy()

# Split into training and testing parts
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X.copy(), y, 
                                                    test_size = 0.25, 
                                                    shuffle=True, 
                                                    random_state=42, 
                                                    stratify=y) #, stratify=y_smote
# Apply SMOTE oversampling technique to the training set
sm = SMOTE(random_state=42)
X_train_smote, y_train_smote = sm.fit_resample(X_train, y_train)
print('Resampled dataset shape %s' % Counter(y_train_smote))
# Out:
# Resampled dataset shape Counter({0: 2739, 1: 2739})

# %%
def accuracy_per_class(classifier, X_test, y_test):
    y_pred = classifier.predict(X_test)

    for y_i in np.unique(y_test)[::-1]:
        print()

        # Find the indices of y_i in the true labels
        indices_i = np.where(y_test == y_i)

        # Computes the accuracy
        print('class', y_i, 'Accuracy: ', str(round(np.sum(y_test[indices_i] == y_pred[indices_i])/ len(np.where(y_test==y_i)[0]), 3)))

# %% [markdown]
# # kNN without SMOTE

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import balanced_accuracy_score

# %%
# Create a kNN instance
kNN_clf = KNeighborsClassifier() 

# Dictionary of possible parameter values per parameter
k_range = list(range(1, 20))
param_grid = dict(n_neighbors=k_range) 

# Grid search step
kNN_model = GridSearchCV(kNN_clf, param_grid, cv=5, scoring='balanced_accuracy', return_train_score=False, verbose=5)
kNN_model.fit(X_train, y_train)

# Print the best parameter and the best score
print("\nBest parameter:", kNN_model.best_params_)
print("Training set cross-validation balanced accuracy score:", kNN_model.best_score_) # average of all cv folds for a single combination of the parameters we specify
print("Test set balanced accuracy score:", balanced_accuracy_score(y_test, kNN_model.predict(X_test)))
# Out:
# Fitting 5 folds for each of 19 candidates, totalling 95 fits
# [CV 1/5] END .....................n_neighbors=1;, score=0.656 total time=   0.0s
# [CV 2/5] END .....................n_neighbors=1;, score=0.641 total time=   0.0s
# [CV 3/5] END .....................n_neighbors=1;, score=0.664 total time=   0.0s
# [CV 4/5] END .....................n_neighbors=1;, score=0.616 total time=   0.0s
# [CV 5/5] END .....................n_neighbors=1;, score=0.578 total time=   0.0s
# [CV 1/5] END .....................n_neighbors=2;, score=0.608 total time=   0.0s
# [CV 2/5] END .....................n_neighbors=2;, score=0.598 total time=   0.0s
# [CV 3/5] END .....................n_neighbors=2;, score=0.608 total time=   0.0s
# [CV 4/5] END .....................n_neighbors=2;, score=0.596 total time=   0.0s
# [CV 5/5] END .....................n_neighbors=2;, score=0.558 total time=   0.0s
# [CV 1/5] END .....................n_neighbors=3;, score=0.629 total time=   0.0s
# [CV 2/5] END .....................n_neighbors=3;, score=0.653 total time=   0.0s
# [CV 3/5] END .....................n_neighbors=3;, score=0.651 total time=   0.0s
# [CV 4/5] END .....................n_neighbors=3;, score=0.638 total time=   0.0s
# [CV 5/5] END .....................n_neighbors=3;, score=0.561 total time=   0.0s
# [CV 1/5] END .....................n_neighbors=4;, score=0.611 total time=   0.0s
# [CV 2/5] END .....................n_neighbors=4;, score=0.620 total time=   0.0s
# [CV 3/5] END .....................n_neighbors=4;, score=0.598 total time=   0.0s
# [CV 4/5] END .....................n_neighbors=4;, score=0.612 total time=   0.0s
# [CV 5/5] END .....................n_neighbors=4;, score=0.543 total time=   0.0s
# [CV 1/5] END .....................n_neighbors=5;, score=0.624 total time=   0.0s
# [CV 2/5] END .....................n_neighbors=5;, score=0.659 total time=   0.0s
# [CV 3/5] END .....................n_neighbors=5;, score=0.629 total time=   0.0s
# [CV 4/5] END .....................n_neighbors=5;, score=0.617 total time=   0.0s
# [CV 5/5] END .....................n_neighbors=5;, score=0.562 total time=   0.0s
# [CV 1/5] END .....................n_neighbors=6;, score=0.619 total time=   0.0s
# [CV 2/5] END .....................n_neighbors=6;, score=0.641 total time=   0.0s
# [CV 3/5] END .....................n_neighbors=6;, score=0.579 total time=   0.0s
# [CV 4/5] END .....................n_neighbors=6;, score=0.616 total time=   0.0s
# [CV 5/5] END .....................n_neighbors=6;, score=0.556 total time=   0.0s
# [CV 1/5] END .....................n_neighbors=7;, score=0.641 total time=   0.0s
# [CV 2/5] END .....................n_neighbors=7;, score=0.654 total time=   0.0s
# [CV 3/5] END .....................n_neighbors=7;, score=0.602 total time=   0.0s
# [CV 4/5] END .....................n_neighbors=7;, score=0.624 total time=   0.0s
# [CV 5/5] END .....................n_neighbors=7;, score=0.575 total time=   0.0s
# [CV 1/5] END .....................n_neighbors=8;, score=0.607 total time=   0.0s
# [CV 2/5] END .....................n_neighbors=8;, score=0.628 total time=   0.0s
# [CV 3/5] END .....................n_neighbors=8;, score=0.583 total time=   0.0s
# [CV 4/5] END .....................n_neighbors=8;, score=0.616 total time=   0.0s
# [CV 5/5] END .....................n_neighbors=8;, score=0.560 total time=   0.0s
# [CV 1/5] END .....................n_neighbors=9;, score=0.620 total time=   0.0s
# [CV 2/5] END .....................n_neighbors=9;, score=0.644 total time=   0.0s
# [CV 3/5] END .....................n_neighbors=9;, score=0.598 total time=   0.0s
# [CV 4/5] END .....................n_neighbors=9;, score=0.631 total time=   0.0s
# [CV 5/5] END .....................n_neighbors=9;, score=0.581 total time=   0.0s
# [CV 1/5] END ....................n_neighbors=10;, score=0.607 total time=   0.0s
# [CV 2/5] END ....................n_neighbors=10;, score=0.629 total time=   0.0s
# [CV 3/5] END ....................n_neighbors=10;, score=0.595 total time=   0.0s
# [CV 4/5] END ....................n_neighbors=10;, score=0.619 total time=   0.0s
# [CV 5/5] END ....................n_neighbors=10;, score=0.559 total time=   0.0s
# [CV 1/5] END ....................n_neighbors=11;, score=0.617 total time=   0.0s
# [CV 2/5] END ....................n_neighbors=11;, score=0.645 total time=   0.0s
# [CV 3/5] END ....................n_neighbors=11;, score=0.592 total time=   0.0s
# [CV 4/5] END ....................n_neighbors=11;, score=0.632 total time=   0.0s
# [CV 5/5] END ....................n_neighbors=11;, score=0.571 total time=   0.0s
# [CV 1/5] END ....................n_neighbors=12;, score=0.613 total time=   0.0s
# [CV 2/5] END ....................n_neighbors=12;, score=0.635 total time=   0.0s
# [CV 3/5] END ....................n_neighbors=12;, score=0.579 total time=   0.0s
# [CV 4/5] END ....................n_neighbors=12;, score=0.620 total time=   0.0s
# [CV 5/5] END ....................n_neighbors=12;, score=0.573 total time=   0.0s
# [CV 1/5] END ....................n_neighbors=13;, score=0.610 total time=   0.0s
# [CV 2/5] END ....................n_neighbors=13;, score=0.640 total time=   0.0s
# [CV 3/5] END ....................n_neighbors=13;, score=0.616 total time=   0.0s
# [CV 4/5] END ....................n_neighbors=13;, score=0.617 total time=   0.0s
# [CV 5/5] END ....................n_neighbors=13;, score=0.576 total time=   0.0s
# [CV 1/5] END ....................n_neighbors=14;, score=0.608 total time=   0.0s
# [CV 2/5] END ....................n_neighbors=14;, score=0.620 total time=   0.0s
# [CV 3/5] END ....................n_neighbors=14;, score=0.590 total time=   0.0s
# [CV 4/5] END ....................n_neighbors=14;, score=0.614 total time=   0.0s
# [CV 5/5] END ....................n_neighbors=14;, score=0.568 total time=   0.0s
# [CV 1/5] END ....................n_neighbors=15;, score=0.611 total time=   0.0s
# [CV 2/5] END ....................n_neighbors=15;, score=0.635 total time=   0.0s
# [CV 3/5] END ....................n_neighbors=15;, score=0.613 total time=   0.0s
# [CV 4/5] END ....................n_neighbors=15;, score=0.630 total time=   0.0s
# [CV 5/5] END ....................n_neighbors=15;, score=0.579 total time=   0.0s
# [CV 1/5] END ....................n_neighbors=16;, score=0.609 total time=   0.0s
# [CV 2/5] END ....................n_neighbors=16;, score=0.631 total time=   0.0s
# [CV 3/5] END ....................n_neighbors=16;, score=0.597 total time=   0.0s
# [CV 4/5] END ....................n_neighbors=16;, score=0.628 total time=   0.0s
# [CV 5/5] END ....................n_neighbors=16;, score=0.568 total time=   0.0s
# [CV 1/5] END ....................n_neighbors=17;, score=0.611 total time=   0.0s
# [CV 2/5] END ....................n_neighbors=17;, score=0.635 total time=   0.0s
# [CV 3/5] END ....................n_neighbors=17;, score=0.607 total time=   0.0s
# [CV 4/5] END ....................n_neighbors=17;, score=0.630 total time=   0.0s
# [CV 5/5] END ....................n_neighbors=17;, score=0.572 total time=   0.0s
# [CV 1/5] END ....................n_neighbors=18;, score=0.611 total time=   0.0s
# [CV 2/5] END ....................n_neighbors=18;, score=0.630 total time=   0.0s
# [CV 3/5] END ....................n_neighbors=18;, score=0.596 total time=   0.0s
# [CV 4/5] END ....................n_neighbors=18;, score=0.621 total time=   0.0s
# [CV 5/5] END ....................n_neighbors=18;, score=0.574 total time=   0.0s
# [CV 1/5] END ....................n_neighbors=19;, score=0.609 total time=   0.0s
# [CV 2/5] END ....................n_neighbors=19;, score=0.635 total time=   0.0s
# [CV 3/5] END ....................n_neighbors=19;, score=0.613 total time=   0.0s
# [CV 4/5] END ....................n_neighbors=19;, score=0.628 total time=   0.0s
# [CV 5/5] END ....................n_neighbors=19;, score=0.583 total time=   0.0s
#
# Best parameter: {'n_neighbors': 1}
# Training set cross-validation balanced accuracy score: 0.6311339637386972
# Test set balanced accuracy score: 0.6150456370938299

# %% [markdown]
# ##### Accuracy per class

# %%
accuracy_per_class(kNN_model, X_test, y_test)
# Out:
# class 1 Accuracy:  0.313
#
# class 0 Accuracy:  0.917

# %% [markdown]
# # kNN with SMOTE oversampling

# %%
# Create a kNN instance
kNN_clf = KNeighborsClassifier() 

# Dictionary of possible parameter values per parameter
k_range = list(range(1, 20))
param_grid = dict(n_neighbors=k_range) 

# Grid search step
kNN_model_smote = GridSearchCV(kNN_clf, param_grid, cv=5, scoring='balanced_accuracy', return_train_score=False, verbose=5)
kNN_model_smote.fit(X_train_smote, y_train_smote)

# Print the best parameter and the best score
print("\nBest parameter:", kNN_model_smote.best_params_)
print("Training set cross-validation balanced accuracy score:", kNN_model_smote.best_score_) # average of all cv folds for a single combination of the parameters we specify
print("Test set balanced accuracy score:", balanced_accuracy_score(y_test, kNN_model_smote.predict(X_test)))
# Out:
# Fitting 5 folds for each of 19 candidates, totalling 95 fits
# [CV 1/5] END .....................n_neighbors=1;, score=0.883 total time=   0.0s
# [CV 2/5] END .....................n_neighbors=1;, score=0.880 total time=   0.0s
# [CV 3/5] END .....................n_neighbors=1;, score=0.885 total time=   0.0s
# [CV 4/5] END .....................n_neighbors=1;, score=0.859 total time=   0.0s
# [CV 5/5] END .....................n_neighbors=1;, score=0.879 total time=   0.0s
# [CV 1/5] END .....................n_neighbors=2;, score=0.887 total time=   0.0s
# [CV 2/5] END .....................n_neighbors=2;, score=0.887 total time=   0.0s
# [CV 3/5] END .....................n_neighbors=2;, score=0.886 total time=   0.0s
# [CV 4/5] END .....................n_neighbors=2;, score=0.859 total time=   0.0s
# [CV 5/5] END .....................n_neighbors=2;, score=0.882 total time=   0.0s
# [CV 1/5] END .....................n_neighbors=3;, score=0.851 total time=   0.0s
# [CV 2/5] END .....................n_neighbors=3;, score=0.848 total time=   0.0s
# [CV 3/5] END .....................n_neighbors=3;, score=0.849 total time=   0.0s
# [CV 4/5] END .....................n_neighbors=3;, score=0.827 total time=   0.0s
# [CV 5/5] END .....................n_neighbors=3;, score=0.852 total time=   0.0s
# [CV 1/5] END .....................n_neighbors=4;, score=0.857 total time=   0.0s
# [CV 2/5] END .....................n_neighbors=4;, score=0.850 total time=   0.0s
# [CV 3/5] END .....................n_neighbors=4;, score=0.871 total time=   0.0s
# [CV 4/5] END .....................n_neighbors=4;, score=0.838 total time=   0.0s
# [CV 5/5] END .....................n_neighbors=4;, score=0.856 total time=   0.0s
# [CV 1/5] END .....................n_neighbors=5;, score=0.825 total time=   0.0s
# [CV 2/5] END .....................n_neighbors=5;, score=0.819 total time=   0.0s
# [CV 3/5] END .....................n_neighbors=5;, score=0.832 total time=   0.0s
# [CV 4/5] END .....................n_neighbors=5;, score=0.821 total time=   0.0s
# [CV 5/5] END .....................n_neighbors=5;, score=0.836 total time=   0.0s
# [CV 1/5] END .....................n_neighbors=6;, score=0.821 total time=   0.0s
# [CV 2/5] END .....................n_neighbors=6;, score=0.819 total time=   0.0s
# [CV 3/5] END .....................n_neighbors=6;, score=0.836 total time=   0.0s
# [CV 4/5] END .....................n_neighbors=6;, score=0.833 total time=   0.0s
# [CV 5/5] END .....................n_neighbors=6;, score=0.852 total time=   0.0s
# [CV 1/5] END .....................n_neighbors=7;, score=0.797 total time=   0.0s
# [CV 2/5] END .....................n_neighbors=7;, score=0.808 total time=   0.0s
# [CV 3/5] END .....................n_neighbors=7;, score=0.815 total time=   0.0s
# [CV 4/5] END .....................n_neighbors=7;, score=0.814 total time=   0.0s
# [CV 5/5] END .....................n_neighbors=7;, score=0.831 total time=   0.0s
# [CV 1/5] END .....................n_neighbors=8;, score=0.804 total time=   0.0s
# [CV 2/5] END .....................n_neighbors=8;, score=0.813 total time=   0.0s
# [CV 3/5] END .....................n_neighbors=8;, score=0.827 total time=   0.0s
# [CV 4/5] END .....................n_neighbors=8;, score=0.816 total time=   0.0s
# [CV 5/5] END .....................n_neighbors=8;, score=0.839 total time=   0.0s
# [CV 1/5] END .....................n_neighbors=9;, score=0.796 total time=   0.0s
# [CV 2/5] END .....................n_neighbors=9;, score=0.797 total time=   0.0s
# [CV 3/5] END .....................n_neighbors=9;, score=0.807 total time=   0.0s
# [CV 4/5] END .....................n_neighbors=9;, score=0.798 total time=   0.0s
# [CV 5/5] END .....................n_neighbors=9;, score=0.825 total time=   0.0s
# [CV 1/5] END ....................n_neighbors=10;, score=0.790 total time=   0.0s
# [CV 2/5] END ....................n_neighbors=10;, score=0.803 total time=   0.0s
# [CV 3/5] END ....................n_neighbors=10;, score=0.814 total time=   0.0s
# [CV 4/5] END ....................n_neighbors=10;, score=0.806 total time=   0.0s
# [CV 5/5] END ....................n_neighbors=10;, score=0.819 total time=   0.0s
# [CV 1/5] END ....................n_neighbors=11;, score=0.784 total time=   0.0s
# [CV 2/5] END ....................n_neighbors=11;, score=0.789 total time=   0.0s
# [CV 3/5] END ....................n_neighbors=11;, score=0.807 total time=   0.0s
# [CV 4/5] END ....................n_neighbors=11;, score=0.787 total time=   0.0s
# [CV 5/5] END ....................n_neighbors=11;, score=0.809 total time=   0.0s
# [CV 1/5] END ....................n_neighbors=12;, score=0.773 total time=   0.0s
# [CV 2/5] END ....................n_neighbors=12;, score=0.793 total time=   0.0s
# [CV 3/5] END ....................n_neighbors=12;, score=0.820 total time=   0.0s
# [CV 4/5] END ....................n_neighbors=12;, score=0.797 total time=   0.0s
# [CV 5/5] END ....................n_neighbors=12;, score=0.809 total time=   0.0s
# [CV 1/5] END ....................n_neighbors=13;, score=0.761 total time=   0.0s
# [CV 2/5] END ....................n_neighbors=13;, score=0.788 total time=   0.0s
# [CV 3/5] END ....................n_neighbors=13;, score=0.800 total time=   0.0s
# [CV 4/5] END ....................n_neighbors=13;, score=0.785 total time=   0.0s
# [CV 5/5] END ....................n_neighbors=13;, score=0.801 total time=   0.0s
# [CV 1/5] END ....................n_neighbors=14;, score=0.761 total time=   0.0s
# [CV 2/5] END ....................n_neighbors=14;, score=0.783 total time=   0.0s
# [CV 3/5] END ....................n_neighbors=14;, score=0.811 total time=   0.0s
# [CV 4/5] END ....................n_neighbors=14;, score=0.785 total time=   0.0s
# [CV 5/5] END ....................n_neighbors=14;, score=0.805 total time=   0.0s
# [CV 1/5] END ....................n_neighbors=15;, score=0.749 total time=   0.0s
# [CV 2/5] END ....................n_neighbors=15;, score=0.768 total time=   0.0s
# [CV 3/5] END ....................n_neighbors=15;, score=0.793 total time=   0.0s
# [CV 4/5] END ....................n_neighbors=15;, score=0.775 total time=   0.0s
# [CV 5/5] END ....................n_neighbors=15;, score=0.794 total time=   0.0s
# [CV 1/5] END ....................n_neighbors=16;, score=0.747 total time=   0.0s
# [CV 2/5] END ....................n_neighbors=16;, score=0.766 total time=   0.0s
# [CV 3/5] END ....................n_neighbors=16;, score=0.796 total time=   0.0s
# [CV 4/5] END ....................n_neighbors=16;, score=0.773 total time=   0.0s
# [CV 5/5] END ....................n_neighbors=16;, score=0.793 total time=   0.0s
# [CV 1/5] END ....................n_neighbors=17;, score=0.736 total time=   0.0s
# [CV 2/5] END ....................n_neighbors=17;, score=0.761 total time=   0.0s
# [CV 3/5] END ....................n_neighbors=17;, score=0.787 total time=   0.0s
# [CV 4/5] END ....................n_neighbors=17;, score=0.764 total time=   0.0s
# [CV 5/5] END ....................n_neighbors=17;, score=0.782 total time=   0.0s
# [CV 1/5] END ....................n_neighbors=18;, score=0.744 total time=   0.0s
# [CV 2/5] END ....................n_neighbors=18;, score=0.761 total time=   0.0s
# [CV 3/5] END ....................n_neighbors=18;, score=0.784 total time=   0.0s
# [CV 4/5] END ....................n_neighbors=18;, score=0.772 total time=   0.0s
# [CV 5/5] END ....................n_neighbors=18;, score=0.778 total time=   0.0s
# [CV 1/5] END ....................n_neighbors=19;, score=0.739 total time=   0.0s
# [CV 2/5] END ....................n_neighbors=19;, score=0.766 total time=   0.0s
# [CV 3/5] END ....................n_neighbors=19;, score=0.775 total time=   0.0s
# [CV 4/5] END ....................n_neighbors=19;, score=0.764 total time=   0.0s
# [CV 5/5] END ....................n_neighbors=19;, score=0.773 total time=   0.0s
#
# Best parameter: {'n_neighbors': 2}
# Training set cross-validation balanced accuracy score: 0.8802489358011183
# Test set balanced accuracy score: 0.6003066812705367
